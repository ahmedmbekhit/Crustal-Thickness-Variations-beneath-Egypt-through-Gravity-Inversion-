# %% [markdown]
# # Moho of Egypt
#
# This notebook applies the proposed gravity inversion method to estimate the Moho of Egypt. We'll use the same cross-validation methods presented in the [synthetic-crust1.ipynb](synthetic-crust1.ipynb) notebook to determined the optimal regularization parameter, density contrast, and reference height. The data used here was downloaded from the [ICGEM web service](http://icgem.gfz-potsdam.de/ICGEM/) and processes in the [process-sam-gravity-data.ipynb](process-sam-gravity-data.ipynb) notebook.

# %% [markdown]
# ## Package imports
#
# Load the necessary libraries to run the inversion and make graphs.

# %%
# Insert the plots into the notebook
# %matplotlib inline

# %% [markdown]
# Load the standard scientific Python stack to numerical analysis and plotting.

# %%
from __future__ import division
import datetime
import zipfile
import cPickle as pickle
import itertools
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import multiprocessing
import seaborn  # Makes the default style of the plots nicer

# %% [markdown]
# The computations generate a lot of run-time warnings. They aren't anything to be concerned about so disable them to avoid clutter.

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# Load the required modules from [Fatiando a Terra](http://www.fatiando.org).

# %%
from fatiando.vis import mpl
from fatiando.gravmag import tesseroid
from fatiando import gridder, utils
from fatiando.inversion import Smoothness2D
import fatiando

# %%
print("Version of Fatiando a Terra used: {}".format(fatiando.__version__))
# Out:
# Version of Fatiando a Terra used: 0.5

# %% [markdown]
# Load our custom classes and functions.

# %%
from datasets import fetch_assumpcao_moho_points
from mohoinv import (MohoGravityInvSpherical, TesseroidRelief, make_mesh,
                     split_data, score_test_set, score_seismic_constraints,
                     score_all, fit_all, predict_seismic)

# %% [markdown]
# Get the number of cores in this computer to run the some things in parallel.

# %%
ncpu = multiprocessing.cpu_count()
print("Number of cores: {}".format(ncpu))
# Out:
# Number of cores: 4

# %% [markdown]
# ## Load the gravity data
#
# Load the processed gravity anomaly data.

# %%
#with open('../data/processed-goco6s-data-egy-h50km.txt') as f:
with open("F:/To upload\working(6-12)/part2.2.Gravity processing and inversion/Gravity_inversion_moho/Gravity processed/processed-gravity/gravity-processed-goco6s-data-sam-h50km.txt") as f:

    for i in range(3):  # Skip the first 2 header lines
        line = f.readline()
    full_shape = [int(x) for x in line.split()[1:]]
    full_lat, full_lon, full_height, full_grav = np.loadtxt(f, usecols=[0, 1, 2, -1],
                                                            unpack=True)
    full_data = [full_lat, full_lon, full_height, full_grav]
print('Number of data points in lat and lon: {}'.format(full_shape))
# Out:
# Number of data points in lat and lon: [101, 111]

# %%
print(full_shape)
# Out:
# [101, 111]

# %% [markdown]
# This is the full dataset. We'll use a portion of it for the inversion and the rest for [cross-validation](#Cross-validation).
#
# Make a plot the data.

# %%
full_area = (full_lat.min(), full_lat.max(), full_lon.min(), full_lon.max())
bm = Basemap(projection='cyl',
             llcrnrlon=full_area[2], urcrnrlon=full_area[3],
             llcrnrlat=full_area[0], urcrnrlat=full_area[1],
             resolution='l')

# %%
x, y = bm(full_lon, full_lat)
ranges = np.abs([full_grav.min(), full_grav.max()]).max()

plt.figure(figsize=(12, 6))
plt.title('Sediment-free Bouguer Anomaly')
bm.contourf(x, y, full_grav, 60, tri=True, cmap='RdBu_r', vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=50).set_label('mGal')
bm.drawmeridians(np.arange(20, 42+1,2), labels=[0, 0, 0, 1], linewidth=0.4)
bm.drawparallels(np.arange(17, 37+1,2), labels=[1, 0, 0, 0], linewidth=0.4)
plt.tight_layout()
plt.savefig('anomaly.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# ## Cross-validation

# %% [markdown]
# The inversion will use only a portion of the data for inversion. The rest will be used for cross-validation to determine an optimal regularization parameter.
#
# We'll use the `split_data` function from [mohoinv.py](mohoinv.py) to separate the dataset into the two parts by taking every other 2 points for inversion and keeping the rest for cross-validation (testing).

# %%
inversion_set, test_set, shape = split_data(full_data, full_shape, every_other=2)

print("Number of inversion grid points: {} x {} = {}".format(shape[0], shape[1],
                                                        shape[0]*shape[1]))
print("Number of test set points: {}".format(test_set[0].size))
# Out:
# Number of inversion grid points: 51 x 56 = 2856
# Number of test set points: 8355

# %% [markdown]
# Plot the inversion data set.

# %%
lat, lon, height, data = inversion_set

# %%
x, y = bm(lon, lat)
ranges = np.abs([data.min(), data.max()]).max()

plt.figure(figsize=(7, 6))
plt.title('Sediment-free Bouguer Anomaly (inversion data)')
bm.contourf(x, y, data, 60, tri=True, cmap='RdBu_r', vmin=-ranges, vmax=ranges)
plt.colorbar(pad=0.01, aspect=50).set_label('mGal')
bm.drawmeridians(np.arange(20, 42+1,2), labels=[0, 0, 0, 1], linewidth=0.2)
bm.drawparallels(np.arange(17, 37+1,2), labels=[1, 0, 0, 0], linewidth=0.2)
plt.tight_layout()
plt.savefig('inversion-data.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# Load the seismic point constraints. This is used in cross-validation to find the reference level and the density contrast.

# %%
infilename="F:/To upload/working(6-12)/part2.2.Gravity processing and inversion/Gravity_inversion_moho/Reciever function seismic moho depth/Seismic_Moho_Globig_Africa_meter.txt"
lon_points=np.loadtxt(infilename)[:,0]
lat_points=np.loadtxt(infilename)[:,1]
seismic_points=np.loadtxt(infilename)[:,2]
test_points=[lat_points, lon_points, seismic_points]
print test_points
# Out:
# [array([  5.17000000e+00,   8.90000000e+00,  -1.13000000e+00,
#          1.15300000e+01,  -1.92000000e+01,  -6.00000000e-01,
#         -2.50200000e+01,  -3.23800000e+01,   3.98000000e+00,
#          2.98000000e+00,   2.70000000e+00,   2.38000000e+00,
#          3.87000000e+00,   2.39000000e+00,   3.52000000e+00,
#          2.94000000e+00,   4.23000000e+00,   4.22000000e+00,
#          4.48000000e+00,   4.59000000e+00,   5.03000000e+00,
#          5.48000000e+00,   5.55000000e+00,   5.72000000e+00,
#          5.97000000e+00,   6.22000000e+00,   6.47000000e+00,
#          6.48000000e+00,   6.37000000e+00,   6.52000000e+00,
#          6.76000000e+00,   7.26000000e+00,   7.36000000e+00,
#          8.47000000e+00,   9.35000000e+00,   9.76000000e+00,
#          1.03300000e+01,   1.06200000e+01,   3.31200000e+01,
#          3.47900000e+01,   3.36900000e+01,   3.42100000e+01,
#          3.39200000e+01,   3.51800000e+01,   3.32500000e+01,
#          3.47300000e+01,   3.45000000e+01,   3.39400000e+01,
#          3.39800000e+01,   3.43800000e+01,   3.36200000e+01,
#          3.19400000e+01,   3.51600000e+01,   3.54500000e+01,
#          3.52100000e+01,   3.40100000e+01,   3.47300000e+01,
#          3.46100000e+01,   3.50800000e+01,   3.55300000e+01,
#          3.50200000e+01,   3.53700000e+01,   3.49400000e+01,
#          3.47500000e+01,   3.55200000e+01,  -4.32000000e+00,
#         -4.96000000e+00,  -6.02000000e+00,  -7.91000000e+00,
#         -5.25000000e+00,  -4.72000000e+00,  -6.94000000e+00,
#         -4.64000000e+00,  -5.30000000e+00,  -5.32000000e+00,
#         -5.37000000e+00,  -3.84000000e+00,  -4.90000000e+00,
#         -2.73000000e+00,  -3.89000000e+00,  -4.84000000e+00,
#         -5.12000000e+00,  -8.98000000e+00,   2.88900000e+01,
#          2.58800000e+01,   2.57900000e+01,   2.73800000e+01,
#          2.97400000e+01,   1.91700000e+01,   3.13900000e+01,
#          1.98800000e+01,   3.24800000e+01,   2.43400000e+01,
#          1.95400000e+01,   2.51900000e+01,   1.77100000e+01,
#          2.82200000e+01,  -2.74000000e+00,  -7.95000000e+00,
#         -9.29000000e+00,  -5.10000000e+00,  -7.51000000e+00,
#         -9.00000000e+00,  -8.57000000e+00,  -8.42000000e+00,
#         -4.88000000e+00,  -6.35000000e+00,   1.63000000e+00,
#         -9.76000000e+00,  -6.83000000e+00,  -7.40000000e+00,
#         -8.31000000e+00,  -8.85000000e+00,  -7.76000000e+00,
#         -8.83000000e+00,  -1.06700000e+01,  -9.37000000e+00,
#         -4.28000000e+00,  -1.84000000e+00,  -2.64000000e+00,
#         -1.36000000e+00,  -3.58000000e+00,  -1.25000000e+00,
#         -4.57000000e+00,   6.60000000e-01,   2.30000000e-01,
#         -3.20000000e-01,   1.07000000e+00,   5.90000000e-01,
#          4.50000000e-01,  -3.82000000e+00,  -2.88000000e+00,
#         -7.76000000e+00,   1.99200000e+01,   2.13100000e+01,
#          2.39300000e+01,   2.28400000e+01,   3.58700000e+01,
#          1.82900000e+01,   1.45000000e+01,   1.43900000e+01,
#          3.17700000e+01,   2.35200000e+01,   2.47200000e+01,
#          2.57800000e+01,   2.12800000e+01,   3.63000000e+01,
#         -1.66000000e+00,  -8.11000000e+00,  -5.08000000e+00,
#          7.79000000e+00,   8.54000000e+00,   8.30000000e+00,
#          9.59000000e+00,   8.93000000e+00,   7.97000000e+00,
#          8.99000000e+00,   8.91000000e+00,   8.73000000e+00,
#          8.12000000e+00,   9.31000000e+00,   8.06000000e+00,
#          8.78000000e+00,   8.99000000e+00,   9.90000000e+00,
#          9.22000000e+00,   1.04200000e+01,   9.39000000e+00,
#          8.61000000e+00,   8.59000000e+00,   9.31000000e+00,
#          9.24000000e+00,   8.70000000e+00,   9.15000000e+00,
#          1.00000000e+01,   7.03000000e+00,   8.78000000e+00,
#          8.85000000e+00,   8.93000000e+00,   7.21000000e+00,
#          9.13000000e+00,   9.11000000e+00,   9.36000000e+00,
#          8.27000000e+00,   8.15000000e+00,   8.14000000e+00,
#          8.30000000e+00,   8.59000000e+00,   8.57000000e+00,
#          8.38000000e+00,   8.88000000e+00,   8.69000000e+00,
#          8.49000000e+00,   7.73000000e+00,   7.64000000e+00,
#          9.83000000e+00,   9.62000000e+00,   9.18000000e+00,
#          8.95000000e+00,   8.75000000e+00,   8.57000000e+00,
#          8.09000000e+00,   7.98000000e+00,   7.88000000e+00,
#          7.69000000e+00,   7.58000000e+00,   7.44000000e+00,
#          9.04000000e+00,   1.15700000e+01,   9.67000000e+00,
#          8.44000000e+00,   9.09000000e+00,   1.03100000e+01,
#          7.03000000e+00,   8.97000000e+00,   7.03000000e+00,
#          9.22000000e+00,   7.68000000e+00,   7.15000000e+00,
#          6.07000000e+00,   6.93000000e+00,   6.16000000e+00,
#          7.56000000e+00,   7.97000000e+00,   1.01700000e+01,
#          1.17900000e+01,   1.21700000e+01,   1.04200000e+01,
#          8.57000000e+00,   8.30000000e+00,   9.12000000e+00,
#         -2.50000000e+00,  -1.13000000e+00,   5.60000000e-01,
#         -1.37000000e+00,   9.80000000e-01,  -1.90100000e+01,
#         -1.52800000e+01,  -2.86100000e+01,   4.44000000e+00,
#          6.68000000e+00,   3.17200000e+01,   2.27900000e+01,
#          2.99300000e+01,  -2.48800000e+01,  -2.48400000e+01,
#         -2.48500000e+01,  -2.38600000e+01,  -2.48900000e+01,
#         -2.57900000e+01,  -2.38700000e+01,  -2.36600000e+01,
#         -2.50100000e+01,  -2.00200000e+01,  -2.09300000e+01,
#         -2.29800000e+01,  -2.99700000e+01,  -2.83600000e+01,
#         -2.69300000e+01,  -2.96700000e+01,  -2.89500000e+01,
#         -2.48500000e+01,  -2.41100000e+01,  -2.57400000e+01,
#         -2.70200000e+01,  -2.68800000e+01,  -2.98700000e+01,
#         -2.78800000e+01,  -2.78500000e+01,  -2.83800000e+01,
#         -2.84300000e+01,  -2.85400000e+01,  -2.86200000e+01,
#         -2.87900000e+01,  -2.71800000e+01,  -2.69000000e+01,
#         -3.06100000e+01,  -2.83200000e+01,  -2.85400000e+01,
#         -2.35200000e+01,  -2.73500000e+01,  -3.33100000e+01,
#         -3.37400000e+01,  -3.16100000e+01,  -2.98700000e+01,
#         -2.86300000e+01,  -2.70000000e+01,  -3.23800000e+01,
#         -1.94700000e+01,  -2.08600000e+01,  -2.06400000e+01,
#         -2.56600000e+01,  -2.60000000e-01,   8.70000000e-01,
#          6.30000000e-01,   6.80000000e-01,  -3.00000000e-02,
#          5.70000000e-01,   5.90000000e-01,   7.40000000e-01,
#          6.60000000e-01,  -1.90000000e-01,   9.10000000e-01,
#          3.20000000e-01,   2.10000000e-01,   9.00000000e-02,
#          7.90000000e-01,   2.10000000e-01,   8.60000000e-01,
#          8.40000000e-01,   3.40000000e-01,   7.80000000e-01,
#          8.40000000e-01,   6.40000000e-01,   3.25200000e+01,
#          3.62800000e+01,   3.21200000e+01,   3.28200000e+01,
#         -3.42900000e+01,  -3.36600000e+01,  -3.28500000e+01,
#         -3.26100000e+01,  -3.19100000e+01,  -3.09200000e+01,
#         -3.09700000e+01,  -2.98500000e+01,  -3.09300000e+01,
#         -3.09800000e+01,  -2.89300000e+01,  -2.79700000e+01,
#         -2.79300000e+01,  -2.39500000e+01,  -2.29700000e+01,
#         -2.90200000e+01,  -2.78600000e+01,  -2.79000000e+01,
#         -2.99800000e+01,  -2.99000000e+01,  -2.01400000e+01,
#         -1.99600000e+01,  -2.10900000e+01,  -2.19000000e+01,
#         -2.18900000e+01,  -2.30100000e+01,  -2.29800000e+01,
#         -2.18500000e+01,  -2.19200000e+01,  -2.22600000e+01,
#         -2.29800000e+01,  -2.23100000e+01,  -2.28200000e+01,
#         -2.19500000e+01,  -2.07600000e+01,  -2.59000000e+01,
#         -2.58500000e+01,  -2.75500000e+01,  -2.68700000e+01,
#         -2.68000000e+01,  -2.59000000e+01,  -2.48400000e+01,
#         -2.38500000e+01,  -2.60300000e+01,  -2.49600000e+01,
#         -2.38000000e+01,  -2.37300000e+01,  -2.35200000e+01,
#         -2.59300000e+01,  -2.89100000e+01,  -2.70700000e+01,
#         -2.59700000e+01,   2.97800000e+01,   3.01100000e+01,
#          2.97600000e+01,   2.99300000e+01,   3.15500000e+01,
#          3.12400000e+01,   3.08900000e+01,   3.07400000e+01,
#          3.06900000e+01,   3.05100000e+01,   3.02600000e+01,
#          3.10400000e+01,   3.06000000e+01,   3.05400000e+01,
#          3.06700000e+01,   3.04100000e+01,   3.05600000e+01,
#          3.00600000e+01,   3.12100000e+01,   1.31400000e+01,
#          3.37200000e+01,   3.33000000e+01,   3.31300000e+01,
#          3.30000000e+01,   3.28800000e+01,   3.25200000e+01,
#          3.23500000e+01,   3.22300000e+01,   3.20800000e+01,
#          3.18600000e+01,   3.27100000e+01,   3.15700000e+01,
#          3.14300000e+01,   3.12900000e+01,   3.10500000e+01,
#          6.19000000e+00,   5.88000000e+00,   6.61000000e+00,
#          2.85000000e+01,   1.09900000e+01,   6.87000000e+00,
#          8.00000000e-01,   2.27000000e+00,   1.42000000e+00,
#          1.73000000e+00,   3.77000000e+00,   3.03000000e+00,
#          4.22000000e+00,   2.12000000e+00,   1.87000000e+00,
#          1.22000000e+00,   1.88000000e+00,   2.20000000e-01,
#          3.50000000e-01,   6.30000000e-01,   8.20000000e-01,
#          7.80000000e-01,   8.00000000e-01,   3.30000000e+00,
#          2.68000000e+00,   1.87000000e+00,   1.55000000e+00,
#         -7.80000000e-01,   3.73000000e+00,   2.00000000e+00,
#          2.30000000e-01,  -2.28300000e+01,  -2.35200000e+01,
#         -2.31700000e+01,  -2.39000000e+01,  -3.20300000e+01,
#         -3.22800000e+01,  -3.24100000e+01,  -3.30200000e+01,
#         -3.31500000e+01,  -3.33300000e+01,  -3.35000000e+01,
#         -3.40100000e+01,  -3.20600000e+01,  -3.22200000e+01,
#         -3.23000000e+01,  -3.23400000e+01,  -3.24600000e+01,
#         -3.30200000e+01,  -3.30600000e+01,   9.77000000e+00,
#          9.38000000e+00,   8.98000000e+00,   8.53000000e+00,
#          8.03000000e+00,   7.73000000e+00,   7.89000000e+00,
#          8.36000000e+00,   8.83000000e+00,   9.19000000e+00,
#          4.28000000e+00,   4.13000000e+00,   3.72000000e+00,
#          3.32000000e+00,   3.08800000e+01,   3.05300000e+01,
#          3.03600000e+01,   3.01100000e+01,   2.99900000e+01,
#          3.01000000e+01,   3.01800000e+01,   3.08700000e+01,
#          3.07200000e+01,   3.05200000e+01,   3.03600000e+01,
#          3.02600000e+01,  -2.97700000e+01,  -2.95200000e+01,
#         -2.92400000e+01,  -2.89900000e+01,  -2.87800000e+01,
#          2.60000000e+01,   2.58900000e+01,   2.57600000e+01,
#          1.47800000e+01,   1.45600000e+01,   1.41200000e+01,
#         -2.14800000e+01,  -2.28000000e+01,   3.27700000e+01,
#          3.30200000e+01,   3.34100000e+01,   3.25400000e+01,
#          3.22100000e+01,   3.16800000e+01,   2.26700000e+01,
#          2.27800000e+01,   2.23100000e+01,   2.24200000e+01,
#          2.25300000e+01,   3.31000000e+01,   3.27800000e+01,
#          3.32100000e+01,   3.20000000e+01,   3.05000000e+01,
#          3.10000000e+01,  -2.05000000e+01,  -2.17500000e+01,
#         -2.20000000e+01,   3.68200000e+01,   3.63100000e+01,
#          3.57800000e+01,   3.55200000e+01,   3.51100000e+01,
#          3.48600000e+01,   3.45400000e+01,   3.40400000e+01,
#          3.35500000e+01,   3.31300000e+01,   3.09500000e+01,
#          3.17700000e+01,   3.22500000e+01,   3.28500000e+01,
#          3.33000000e+01,   3.36700000e+01,   3.13400000e+01,
#          3.19400000e+01,   3.26300000e+01,   3.30700000e+01,
#          3.34700000e+01,   3.25200000e+01,   3.31200000e+01,
#         -3.35000000e+01,  -3.35000000e+01,   3.57000000e+01,
#          3.51500000e+01,   3.45000000e+01,   3.41500000e+01,
#          3.33500000e+01,   3.30000000e+01,   3.50400000e+01,
#          3.48300000e+01,   3.47800000e+01,   3.46200000e+01,
#          3.43200000e+01,   7.53340000e+00,   1.04334000e+01,
#          1.01168000e+01,   6.86670000e+00,   6.23350000e+00,
#          2.70517000e+01,   2.53405000e+01,   2.38559000e+01,
#          2.50131000e+01,   2.78925000e+01,   2.92166000e+01,
#          2.99293000e+01,   2.99275000e+01,   2.85229000e+01,
#          2.86226000e+01,   3.10470000e+01,   3.14916000e+01,
#          2.92433000e+01,   2.71484000e+01,   2.76821000e+01,
#          2.38022000e+01,   2.39169000e+01,   2.32931000e+01,
#          2.29226000e+01,   2.33829000e+01,   2.34130000e+01,
#          2.36684000e+01,   2.35217000e+01,   2.89893000e+01,
#          2.40040000e+01,   2.43195000e+01,   2.81889000e+01,
#          2.93103000e+01,   2.84317000e+01,   2.90548000e+01,
#          2.91686000e+01,   2.85511000e+01,   4.22300000e+00,
#          4.48100000e+00,   4.58800000e+00,   5.03400000e+00,
#          5.48000000e+00,   5.54600000e+00,   5.72300000e+00,
#          5.97500000e+00,   6.22500000e+00,   6.46700000e+00,
#          6.47700000e+00,   6.37000000e+00,   6.52300000e+00,
#          6.76000000e+00,   7.26500000e+00,   7.35900000e+00,
#          8.46900000e+00,   9.34700000e+00,   9.75700000e+00,
#          1.03270000e+01,   1.06190000e+01,   3.48400000e+01,
#          3.49800000e+01,   3.51800000e+01,   3.12400000e+01,
#          3.12000000e+01,   3.11400000e+01,   3.09900000e+01,
#          3.09700000e+01,   3.08700000e+01,   3.08700000e+01,
#          3.07900000e+01,   3.07300000e+01,   3.06200000e+01,
#          3.06000000e+01,   3.03300000e+01,   3.09200000e+01,
#          3.01800000e+01,   3.00500000e+01,   2.99000000e+01,
#          2.97900000e+01,   2.97200000e+01,   3.21220000e+01,
#          3.25230000e+01,   3.49600000e+01,   2.99270000e+01,
#          1.52300000e+01,   1.58960000e+01,   1.57090000e+01,
#         -2.69300000e+01,  -2.70700000e+01,  -2.70000000e+01,
#         -2.68700000e+01,  -2.69000000e+01,  -2.68100000e+01,
#         -2.70200000e+01,  -2.59700000e+01,  -2.59300000e+01,
#         -2.59000000e+01,  -2.59000000e+01,  -2.56700000e+01,
#         -2.48800000e+01,  -2.48400000e+01,  -2.48500000e+01,
#         -2.49000000e+01,  -2.38700000e+01,  -2.38600000e+01,
#         -2.38000000e+01,  -2.41100000e+01,  -2.29800000e+01,
#         -2.30100000e+01,  -2.48400000e+01,  -2.38500000e+01,
#         -2.39500000e+01,  -2.48500000e+01,  -2.36600000e+01,
#         -2.29700000e+01,  -2.28200000e+01,  -2.19000000e+01,
#         -2.18900000e+01,  -2.19500000e+01,  -2.23100000e+01,
#         -2.10900000e+01,  -2.09300000e+01,  -2.01400000e+01,
#         -2.08600000e+01,  -2.58500000e+01,  -2.28800000e+01,
#         -2.22600000e+01,  -2.50200000e+01,  -1.87460000e+01,
#         -1.85790000e+01,  -1.82950000e+01,  -1.99010000e+01,
#         -1.99010000e+01,  -2.05490000e+01,  -2.01640000e+01,
#         -1.96630000e+01,  -1.89130000e+01,  -1.90160000e+01,
#         -1.90160000e+01,  -1.96310000e+01,  -1.92940000e+01,
#         -2.11210000e+01,  -2.04740000e+01,  -2.02180000e+01,
#         -2.22380000e+01,  -2.13930000e+01,  -2.28250000e+01,
#         -2.29690000e+01,  -2.28180000e+01,  -2.19000000e+01,
#         -2.45153500e+01,  -2.41135200e+01,  -2.29930700e+01,
#         -1.85395600e+01,  -1.78001700e+01,  -2.19464100e+01,
#         -2.14035500e+01,  -2.13619200e+01,  -2.28538200e+01,
#         -2.33803900e+01,  -2.54755300e+01,  -1.93893100e+01,
#         -2.01956800e+01,  -2.10996800e+01,  -2.05628500e+01,
#         -2.25696700e+01,  -2.33630300e+01,  -2.58118500e+01,
#         -1.99016800e+01,  -2.50150000e+01,   3.37327800e+01,
#          3.36884300e+01,   3.36490100e+01,   3.36243700e+01,
#          3.35800100e+01,   3.35504500e+01,   3.35307300e+01,
#          3.34962400e+01,   3.34863800e+01,   3.34321700e+01,
#          3.33779700e+01,   3.33336100e+01,   3.32744800e+01,
#          3.32301200e+01,   3.31808400e+01,   3.31315600e+01,
#          3.30724300e+01,   3.30231500e+01,   3.29738700e+01,
#          3.29147300e+01,   3.29048800e+01,   3.26461500e+01,
#          3.25968700e+01,   3.25549900e+01,   3.25032400e+01,
#          3.24391800e+01,   3.23874300e+01,   3.23356900e+01,
#          3.22740900e+01,   3.22174200e+01,   3.21533500e+01,
#          3.20892900e+01,   3.20326200e+01,   3.19759400e+01,
#          3.19192700e+01,   3.18872400e+01,   3.18527400e+01,
#          3.18133200e+01,   3.17837500e+01,   3.38880200e+01,
#          3.38165640e+01,   3.37278590e+01,   3.36292990e+01,
#          3.35627710e+01,   3.34888500e+01,   3.34075380e+01,
#          3.33311540e+01,   3.32547690e+01,   3.31636010e+01,
#          3.31069290e+01,   3.30379360e+01,   3.29640160e+01,
#          3.28950240e+01,   3.28235670e+01,   3.27373270e+01,
#          3.26757270e+01,   3.25993430e+01,   3.25377420e+01,
#          3.24687500e+01,   3.23972940e+01,   3.23332290e+01,
#          3.22839490e+01,   3.22297410e+01,   3.21644450e+01,
#          3.20942200e+01,   3.20350840e+01,   3.19710200e+01,
#          3.19168120e+01,   3.18724590e+01,   3.18145550e+01,
#          3.17578830e+01,   3.17024430e+01,   3.16506980e+01,
#          3.15964900e+01,   3.15459780e+01,   3.15065540e+01,
#          3.14695940e+01,   3.14363300e+01,   3.14006010e+01,
#          3.13611770e+01,   3.13266810e+01,   3.12884890e+01,
#          3.12244250e+01,   3.11751440e+01,   3.11209360e+01,
#          3.10568720e+01,   3.09558480e+01,   3.08622150e+01,
#          3.38043090e+01,   3.37360070e+01,   3.36297590e+01,
#          3.35462790e+01,   3.34552100e+01,   3.33413730e+01,
#          3.32237420e+01,   3.30909330e+01,   3.29770960e+01,
#          3.28746430e+01,   3.27721900e+01,   3.26735320e+01,
#          3.25786680e+01,   3.24762150e+01,   3.23737620e+01,
#          3.22447470e+01,   3.21195270e+01,   3.19981010e+01,
#          3.18965970e+01,   3.17903500e+01,   3.16689240e+01,
#          3.39731660e+01,   3.38688160e+01,   3.37151370e+01,
#          3.35804300e+01,   3.33968690e+01,   3.32716480e+01,
#          3.31217630e+01,   3.29386760e+01,   3.27413600e+01,
#          3.25971670e+01,   3.24245140e+01,   3.22689380e+01,
#          3.21403970e+01,   3.20037930e+01,   3.18354100e+01,
#          3.16627580e+01,   3.14388790e+01,   3.12045660e+01,
#          3.09787900e+01,   3.08497750e+01,   3.07188630e+01,
#          3.05414670e+01,   3.03612260e+01,   3.02037520e+01,
#          3.00334720e+01,   2.98171820e+01,   3.49333330e+01,
#          3.48833330e+01,   3.46500000e+01,  -2.13520000e+01,
#         -2.13047000e+01,  -2.10224000e+01,  -2.12304000e+01,
#         -2.05438000e+01,  -2.02141000e+01,  -2.03636000e+01,
#         -1.98746000e+01,  -1.91093000e+01,  -1.87522000e+01,
#         -1.80782000e+01,  -1.78654000e+01,  -1.81599000e+01,
#         -1.72172000e+01,  -1.70035000e+01,  -1.73335000e+01,
#         -1.87765000e+01,  -1.91753000e+01,  -1.90438000e+01,
#         -1.86871000e+01,  -1.96217000e+01,  -1.98701000e+01,
#         -1.91244000e+01,  -1.93302000e+01,  -1.85625000e+01,
#         -1.82287000e+01,  -1.74340000e+01,  -1.78075000e+01,
#         -2.17590000e+01,  -2.13500000e+01,  -2.06120000e+01,
#         -2.01510000e+01,  -1.92020000e+01]), array([  1.84200000e+01,   3.66900000e+01,   3.73500000e+01,
#          4.28500000e+01,   1.75800000e+01,   3.07400000e+01,
#          2.56000000e+01,   2.08100000e+01,   1.31900000e+01,
#          1.19600000e+01,   1.32900000e+01,   1.12700000e+01,
#          1.14600000e+01,   9.83000000e+00,   1.50300000e+01,
#          9.91000000e+00,   9.33000000e+00,   1.06200000e+01,
#          1.16300000e+01,   9.46000000e+00,   9.93000000e+00,
#          1.05700000e+01,   1.23100000e+01,   9.36000000e+00,
#          1.12300000e+01,   1.00500000e+01,   1.26200000e+01,
#          1.32700000e+01,   1.07900000e+01,   1.42900000e+01,
#          1.18100000e+01,   1.35500000e+01,   1.26700000e+01,
#          1.32400000e+01,   1.33800000e+01,   1.39500000e+01,
#          1.52600000e+01,   1.43700000e+01,  -7.25000000e+00,
#         -6.25000000e+00,  -5.99000000e+00,  -6.33000000e+00,
#         -6.75000000e+00,  -2.43000000e+00,  -5.06000000e+00,
#         -2.79000000e+00,  -2.23000000e+00,  -3.84000000e+00,
#         -3.03000000e+00,  -2.16000000e+00,  -4.45000000e+00,
#         -4.46000000e+00,  -2.57000000e+00,  -5.41000000e+00,
#         -3.89000000e+00,  -5.47000000e+00,  -5.43000000e+00,
#         -4.41000000e+00,  -4.17000000e+00,  -5.18000000e+00,
#         -5.40000000e+00,  -5.97000000e+00,  -4.77000000e+00,
#         -3.80000000e+00,  -2.94000000e+00,   3.51400000e+01,
#          3.43500000e+01,   3.40600000e+01,   3.33200000e+01,
#          3.54000000e+01,   3.31800000e+01,   3.35200000e+01,
#          3.47300000e+01,   3.86200000e+01,   3.65700000e+01,
#          3.64700000e+01,   3.67200000e+01,   3.58000000e+01,
#          3.67000000e+01,   3.60200000e+01,   2.96900000e+01,
#          3.04000000e+01,   3.32400000e+01,   3.58800000e+01,
#          4.32400000e+01,   3.92600000e+01,   4.17900000e+01,
#          3.58400000e+01,   4.22100000e+01,   3.73200000e+01,
#          4.16000000e+01,   3.84000000e+01,   3.79900000e+01,
#          4.34800000e+01,   4.96900000e+01,   4.35400000e+01,
#          3.65500000e+01,   3.67000000e+01,   3.16200000e+01,
#          3.27700000e+01,   3.03900000e+01,   3.10400000e+01,
#          3.32500000e+01,   3.20600000e+01,   3.31600000e+01,
#          2.96300000e+01,   3.10600000e+01,   3.36000000e+01,
#          3.53000000e+01,   3.76700000e+01,   3.69900000e+01,
#          3.53100000e+01,   3.48300000e+01,   3.56700000e+01,
#          3.40300000e+01,   3.56500000e+01,   3.47900000e+01,
#          3.04200000e+01,   3.16700000e+01,   3.13200000e+01,
#          3.18100000e+01,   3.07100000e+01,   2.99900000e+01,
#          3.00900000e+01,   3.02800000e+01,   3.23200000e+01,
#          3.17300000e+01,   3.41200000e+01,   3.13900000e+01,
#          3.31800000e+01,   3.26400000e+01,   3.22200000e+01,
#          3.57500000e+01,   4.26900000e+01,   4.27800000e+01,
#          4.30400000e+01,   4.43200000e+01,   4.15200000e+01,
#          4.23800000e+01,  -4.01000000e+00,  -1.69600000e+01,
#          3.52000000e+01,   4.55000000e+01,   4.66400000e+01,
#          4.23600000e+01,   4.03400000e+01,   2.73000000e+00,
#          1.36100000e+01,   3.32600000e+01,   3.20800000e+01,
#          3.99100000e+01,   3.89000000e+01,   3.90900000e+01,
#          3.97300000e+01,   3.94200000e+01,   3.91300000e+01,
#          4.01700000e+01,   4.07700000e+01,   3.95500000e+01,
#          3.83800000e+01,   3.87600000e+01,   3.95600000e+01,
#          3.90000000e+01,   3.98400000e+01,   3.91400000e+01,
#          4.11100000e+01,   3.99400000e+01,   3.94000000e+01,
#          3.86100000e+01,   4.03200000e+01,   4.02000000e+01,
#          4.07600000e+01,   3.98000000e+01,   3.90200000e+01,
#          3.99000000e+01,   3.92800000e+01,   3.98600000e+01,
#          4.00100000e+01,   3.99300000e+01,   3.86000000e+01,
#          4.01700000e+01,   4.00100000e+01,   4.02200000e+01,
#          3.95000000e+01,   3.93500000e+01,   3.92400000e+01,
#          3.89500000e+01,   3.91300000e+01,   3.92900000e+01,
#          3.96800000e+01,   3.91500000e+01,   3.89000000e+01,
#          3.98300000e+01,   3.86500000e+01,   3.87200000e+01,
#          3.84000000e+01,   3.85700000e+01,   3.89300000e+01,
#          3.91100000e+01,   3.92800000e+01,   3.94500000e+01,
#          3.98100000e+01,   3.99100000e+01,   3.99600000e+01,
#          4.01200000e+01,   4.02200000e+01,   4.03200000e+01,
#          3.87700000e+01,   3.73900000e+01,   3.95300000e+01,
#          3.63300000e+01,   3.65200000e+01,   3.77300000e+01,
#          3.99800000e+01,   3.77700000e+01,   3.92800000e+01,
#          4.11100000e+01,   3.68300000e+01,   3.71800000e+01,
#          3.75600000e+01,   3.84700000e+01,   3.82100000e+01,
#          3.78600000e+01,   3.91300000e+01,   4.06500000e+01,
#          4.10000000e+01,   3.96800000e+01,   3.99400000e+01,
#          3.92900000e+01,   3.77800000e+01,   4.02500000e+01,
#          3.68000000e+01,   3.68000000e+01,   3.48000000e+01,
#          3.80000000e+01,   3.49800000e+01,   4.72300000e+01,
#          2.81900000e+01,   2.52600000e+01,   1.85500000e+01,
#         -4.86000000e+00,   3.50900000e+01,   5.53000000e+00,
#          3.18300000e+01,   2.61600000e+01,   2.71100000e+01,
#          2.81600000e+01,   2.81600000e+01,   2.92200000e+01,
#          3.00700000e+01,   2.71700000e+01,   2.60800000e+01,
#          2.53400000e+01,   3.05200000e+01,   2.71400000e+01,
#          2.83000000e+01,   2.09500000e+01,   2.12500000e+01,
#          2.30400000e+01,   2.27600000e+01,   2.22000000e+01,
#          2.51400000e+01,   2.93300000e+01,   2.82800000e+01,
#          2.90900000e+01,   3.01300000e+01,   2.40200000e+01,
#          2.42400000e+01,   2.51300000e+01,   2.45900000e+01,
#          2.46300000e+01,   2.46800000e+01,   2.46300000e+01,
#          2.49300000e+01,   2.53300000e+01,   2.71800000e+01,
#          2.55000000e+01,   2.76200000e+01,   2.46800000e+01,
#          3.14000000e+01,   3.17100000e+01,   2.65100000e+01,
#          2.02700000e+01,   2.02300000e+01,   2.40200000e+01,
#          2.43100000e+01,   2.50200000e+01,   2.08100000e+01,
#          3.07700000e+01,   2.90000000e+01,   2.98500000e+01,
#          2.92200000e+01,   3.01000000e+01,   3.04700000e+01,
#          3.06500000e+01,   3.04600000e+01,   3.01500000e+01,
#          3.03100000e+01,   3.07400000e+01,   3.03800000e+01,
#          3.05700000e+01,   2.99000000e+01,   3.03600000e+01,
#          3.04900000e+01,   3.04500000e+01,   2.99000000e+01,
#          3.02200000e+01,   3.00100000e+01,   3.01700000e+01,
#          3.02300000e+01,   3.00400000e+01,   3.01300000e+01,
#          3.01700000e+01,   3.00300000e+01,   2.08800000e+01,
#          7.47000000e+00,   1.30900000e+01,  -4.61000000e+00,
#          1.92500000e+01,   2.13400000e+01,   1.96200000e+01,
#          2.15400000e+01,   2.20700000e+01,   2.29900000e+01,
#          2.39100000e+01,   2.22500000e+01,   2.12700000e+01,
#          2.22500000e+01,   2.32300000e+01,   2.20100000e+01,
#          2.34100000e+01,   2.40200000e+01,   2.62000000e+01,
#          2.62000000e+01,   2.72900000e+01,   2.80700000e+01,
#          2.31400000e+01,   2.50300000e+01,   2.86100000e+01,
#          3.13200000e+01,   2.63400000e+01,   2.63700000e+01,
#          2.72700000e+01,   2.90700000e+01,   3.00200000e+01,
#          3.02800000e+01,   3.09400000e+01,   2.92100000e+01,
#          2.83000000e+01,   2.92700000e+01,   2.72200000e+01,
#          2.81900000e+01,   3.09200000e+01,   2.61500000e+01,
#          2.62700000e+01,   2.61800000e+01,   2.62800000e+01,
#          2.81000000e+01,   2.71500000e+01,   2.44600000e+01,
#          2.49600000e+01,   3.09000000e+01,   3.03100000e+01,
#          2.89000000e+01,   3.06700000e+01,   3.14000000e+01,
#          2.50800000e+01,   2.48300000e+01,   2.41700000e+01,
#          2.37200000e+01,  -9.03000000e+00,  -8.51000000e+00,
#         -8.03000000e+00,  -7.34000000e+00,  -7.75000000e+00,
#         -7.47000000e+00,  -6.97000000e+00,  -6.69000000e+00,
#         -6.46000000e+00,  -6.12000000e+00,  -5.65000000e+00,
#         -6.55000000e+00,  -7.26000000e+00,  -7.99000000e+00,
#         -8.67000000e+00,  -8.88000000e+00,  -9.65000000e+00,
#         -9.24000000e+00,  -8.96000000e+00,   1.70000000e+00,
#         -5.32000000e+00,  -5.11000000e+00,  -5.03000000e+00,
#         -4.90000000e+00,  -4.89000000e+00,  -4.57000000e+00,
#         -4.65000000e+00,  -4.62000000e+00,  -4.39000000e+00,
#         -4.27000000e+00,  -4.73000000e+00,  -4.19000000e+00,
#         -4.24000000e+00,  -4.11000000e+00,  -4.00000000e+00,
#         -3.70000000e-01,   4.00000000e-02,   4.40000000e-01,
#         -9.85000000e+00,   8.12000000e+00,   7.42000000e+00,
#          3.41200000e+01,   3.76100000e+01,   3.71600000e+01,
#          3.57700000e+01,   3.86300000e+01,   3.81000000e+01,
#          3.97100000e+01,   3.73000000e+01,   3.67900000e+01,
#          3.47600000e+01,   3.63100000e+01,   3.41300000e+01,
#          3.54000000e+01,   3.60800000e+01,   3.62800000e+01,
#          3.71100000e+01,   3.80200000e+01,   3.60600000e+01,
#          3.66300000e+01,   3.72600000e+01,   3.78300000e+01,
#          3.63700000e+01,   3.59400000e+01,   3.59900000e+01,
#          3.61300000e+01,   2.06900000e+01,   2.06100000e+01,
#          2.11600000e+01,   2.11900000e+01,   2.15200000e+01,
#          2.16600000e+01,   2.18000000e+01,   2.19500000e+01,
#          2.20300000e+01,   2.21700000e+01,   2.21700000e+01,
#          2.23500000e+01,   2.13800000e+01,   2.15000000e+01,
#          2.15300000e+01,   2.15600000e+01,   2.20000000e+01,
#          2.20300000e+01,   2.20700000e+01,   3.84800000e+01,
#          3.86900000e+01,   3.91300000e+01,   3.95800000e+01,
#          3.96900000e+01,   4.00600000e+01,   3.87300000e+01,
#          3.89800000e+01,   3.98400000e+01,   4.01400000e+01,
#          3.58900000e+01,   3.59200000e+01,   3.58400000e+01,
#          3.59900000e+01,   3.47500000e+01,   3.52700000e+01,
#          3.55400000e+01,   3.59100000e+01,   3.60100000e+01,
#          3.59000000e+01,   3.57500000e+01,   3.47700000e+01,
#          3.50500000e+01,   3.52900000e+01,   3.55100000e+01,
#          3.56900000e+01,   1.78600000e+01,   1.85300000e+01,
#          1.92400000e+01,   1.99600000e+01,   2.05000000e+01,
#          3.40100000e+01,   3.34100000e+01,   3.26300000e+01,
#          4.31800000e+01,   4.33400000e+01,   4.36400000e+01,
#          1.42500000e+01,   1.47500000e+01,  -4.99000000e+00,
#         -5.06000000e+00,  -5.25000000e+00,  -4.76000000e+00,
#         -4.43000000e+00,  -4.22000000e+00,  -1.56200000e+01,
#         -1.61000000e+01,  -1.51800000e+01,  -1.57200000e+01,
#         -1.62900000e+01,  -8.50000000e+00,  -8.11000000e+00,
#         -8.51000000e+00,  -7.00000000e+00,  -6.50000000e+00,
#         -8.50000000e+00,   3.07000000e+01,   3.04000000e+01,
#          3.04000000e+01,   8.81000000e+00,   8.82000000e+00,
#          8.84000000e+00,   8.85000000e+00,   8.84000000e+00,
#          8.86000000e+00,   8.87000000e+00,   8.89000000e+00,
#          8.90000000e+00,   8.93000000e+00,  -3.89000000e+00,
#         -4.17000000e+00,  -4.47000000e+00,  -4.96000000e+00,
#         -5.13000000e+00,  -5.18000000e+00,  -4.15000000e+00,
#         -4.42000000e+00,  -4.59000000e+00,  -5.05000000e+00,
#         -5.26000000e+00,  -7.91000000e+00,  -8.51000000e+00,
#          2.46200000e+01,   2.21000000e+01,  -5.75000000e+00,
#         -5.25000000e+00,  -5.20000000e+00,  -5.20000000e+00,
#         -5.20000000e+00,  -5.00000000e+00,  -2.51000000e+00,
#         -3.26000000e+00,  -3.85000000e+00,  -4.65000000e+00,
#         -5.70000000e+00,   4.53360000e+00,   7.63340000e+00,
#          9.11670000e+00,   7.41670000e+00,   7.10010000e+00,
#          3.36081000e+01,   3.45021000e+01,   3.41143000e+01,
#          3.48386000e+01,   3.41322000e+01,   3.47327000e+01,
#          3.39804000e+01,   3.18291000e+01,   3.39927000e+01,
#          3.12945000e+01,   2.85038000e+01,   2.52122000e+01,
#          2.54556000e+01,   2.83104000e+01,   3.09175000e+01,
#          3.27780000e+01,   3.30749000e+01,   3.26647000e+01,
#          3.23258000e+01,   3.25779000e+01,   3.24488000e+01,
#          3.27911000e+01,   3.24074000e+01,   3.46397000e+01,
#          3.26510000e+01,   2.89546000e+01,   3.52689000e+01,
#          3.50650000e+01,   3.51014000e+01,   3.49297000e+01,
#          3.51094000e+01,   3.48717000e+01,   1.06190000e+01,
#          1.16340000e+01,   9.46200000e+00,   9.93300000e+00,
#          1.05720000e+01,   1.23120000e+01,   9.35500000e+00,
#          1.12320000e+01,   1.00540000e+01,   1.26200000e+01,
#          1.32680000e+01,   1.07930000e+01,   1.42880000e+01,
#          1.18110000e+01,   1.35480000e+01,   1.26670000e+01,
#          1.32370000e+01,   1.33850000e+01,   1.39500000e+01,
#          1.52620000e+01,   1.43720000e+01,   2.40900000e+01,
#          2.48900000e+01,   2.55000000e+01,   3.47100000e+01,
#          3.45400000e+01,   3.47800000e+01,   3.49200000e+01,
#          3.46900000e+01,   3.47900000e+01,   3.50800000e+01,
#          3.47700000e+01,   3.47700000e+01,   3.49000000e+01,
#          3.47900000e+01,   3.49500000e+01,   3.50200000e+01,
#          3.50200000e+01,   3.50400000e+01,   3.49500000e+01,
#          3.49100000e+01,   3.50500000e+01,   1.30890000e+01,
#          2.08780000e+01,   3.33300000e+01,   3.18290000e+01,
#          3.24900000e+01,   3.24100000e+01,   3.33180000e+01,
#          2.30400000e+01,   2.41700000e+01,   2.50200000e+01,
#          2.62900000e+01,   2.71800000e+01,   2.81000000e+01,
#          2.90900000e+01,   2.37200000e+01,   2.50900000e+01,
#          2.61500000e+01,   2.71500000e+01,   2.92200000e+01,
#          2.61600000e+01,   2.71100000e+01,   2.81600000e+01,
#          2.92200000e+01,   2.71700000e+01,   2.81600000e+01,
#          2.89000000e+01,   2.93300000e+01,   2.83000000e+01,
#          2.90700000e+01,   2.44600000e+01,   2.49600000e+01,
#          2.40200000e+01,   2.51400000e+01,   2.60800000e+01,
#          2.62000000e+01,   2.72200000e+01,   2.63700000e+01,
#          2.72700000e+01,   2.81900000e+01,   2.92700000e+01,
#          2.63400000e+01,   2.71400000e+01,   2.86100000e+01,
#          2.90000000e+01,   2.62700000e+01,   2.83400000e+01,
#          2.92100000e+01,   2.56000000e+01,   2.21970000e+01,
#          2.19940000e+01,   2.17920000e+01,   2.35270000e+01,
#          2.35270000e+01,   2.26490000e+01,   2.24590000e+01,
#          2.21940000e+01,   2.25430000e+01,   2.23160000e+01,
#          2.23160000e+01,   2.38270000e+01,   2.29090000e+01,
#          2.47640000e+01,   2.45140000e+01,   2.41320000e+01,
#          2.67180000e+01,   2.55810000e+01,   2.72290000e+01,
#          2.62020000e+01,   2.72220000e+01,   2.63730000e+01,
#          2.39327900e+01,   2.17823000e+01,   2.01955500e+01,
#          2.13382200e+01,   2.51618900e+01,   2.54469100e+01,
#          2.37717700e+01,   2.12157100e+01,   2.22067900e+01,
#          2.46607900e+01,   2.28572900e+01,   2.21624600e+01,
#          2.45371900e+01,   2.73342400e+01,   2.62178500e+01,
#          2.74468200e+01,   2.58596100e+01,   2.48008500e+01,
#          2.35273300e+01,   2.55970000e+01,   3.24675600e+01,
#          3.25907600e+01,   3.27287400e+01,   3.28322300e+01,
#          3.29258700e+01,   3.29948600e+01,   3.30687800e+01,
#          3.31574800e+01,   3.32461900e+01,   3.33891000e+01,
#          3.35468000e+01,   3.36946400e+01,   3.38572600e+01,
#          3.40001700e+01,   3.41628000e+01,   3.43303500e+01,
#          3.44979000e+01,   3.46506700e+01,   3.48083700e+01,
#          3.49512800e+01,   3.50892700e+01,   3.31457800e+01,
#          3.32320200e+01,   3.33207200e+01,   3.34069600e+01,
#          3.35203100e+01,   3.36065500e+01,   3.37051100e+01,
#          3.38061300e+01,   3.39170100e+01,   3.40205000e+01,
#          3.41239900e+01,   3.42225500e+01,   3.43087900e+01,
#          3.44024200e+01,   3.44738800e+01,   3.45354800e+01,
#          3.46020100e+01,   3.46537500e+01,   3.26505170e+01,
#          3.26874770e+01,   3.27244370e+01,   3.27761820e+01,
#          3.28032860e+01,   3.28402460e+01,   3.28747420e+01,
#          3.29166300e+01,   3.29609820e+01,   3.30225830e+01,
#          3.30620070e+01,   3.31186790e+01,   3.31704230e+01,
#          3.32147760e+01,   3.32517360e+01,   3.32985520e+01,
#          3.33404400e+01,   3.33897200e+01,   3.34291440e+01,
#          3.34685690e+01,   3.34981370e+01,   3.35326330e+01,
#          3.35671290e+01,   3.35979290e+01,   3.36459770e+01,
#          3.36940260e+01,   3.37445380e+01,   3.37864260e+01,
#          3.38184580e+01,   3.38628100e+01,   3.38923780e+01,
#          3.39293390e+01,   3.39650670e+01,   3.39934030e+01,
#          3.40291310e+01,   3.40833390e+01,   3.41461710e+01,
#          3.41942200e+01,   3.42521240e+01,   3.43186520e+01,
#          3.43716280e+01,   3.44209090e+01,   3.44825090e+01,
#          3.45539650e+01,   3.46352780e+01,   3.46845580e+01,
#          3.47264460e+01,   3.47683340e+01,   3.47929740e+01,
#          2.70773480e+01,   2.72215410e+01,   2.74568040e+01,
#          2.76579150e+01,   2.78931770e+01,   2.81398230e+01,
#          2.84054420e+01,   2.86900330e+01,   2.89480630e+01,
#          2.91985030e+01,   2.94072040e+01,   2.96462610e+01,
#          2.98549610e+01,   3.01054020e+01,   3.03216910e+01,
#          3.06138720e+01,   3.08984630e+01,   3.11640820e+01,
#          3.13784740e+01,   3.16365040e+01,   3.18755610e+01,
#          2.70773480e+01,   2.72329250e+01,   2.74549060e+01,
#          2.76503260e+01,   2.78998180e+01,   2.80743670e+01,
#          2.82925540e+01,   2.85467890e+01,   2.88256890e+01,
#          2.90362860e+01,   2.92715490e+01,   2.94954270e+01,
#          2.96728230e+01,   2.98549610e+01,   3.00902230e+01,
#          3.03330750e+01,   3.06366390e+01,   3.09572790e+01,
#          3.12532540e+01,   3.14315980e+01,   3.16118390e+01,
#          3.18461530e+01,   3.20965930e+01,   3.23014990e+01,
#          3.25377100e+01,   3.28185070e+01,   3.26000000e+01,
#          3.26333330e+01,   3.26833330e+01,   1.54404000e+01,
#          1.44751000e+01,   1.46821000e+01,   1.49014000e+01,
#          1.44624000e+01,   1.50127000e+01,   1.35200000e+01,
#          1.29769000e+01,   1.25910000e+01,   1.23690000e+01,
#          1.38847000e+01,   1.30281000e+01,   1.25578000e+01,
#          1.24278000e+01,   1.32443000e+01,   1.38378000e+01,
#          1.29328000e+01,   1.58845000e+01,   1.44791000e+01,
#          1.49459000e+01,   1.48483000e+01,   1.39101000e+01,
#          1.36138000e+01,   1.31570000e+01,   1.36773000e+01,
#          1.32737000e+01,   1.32736000e+01,   1.23304000e+01,
#          1.39860000e+01,   1.47490000e+01,   1.73350000e+01,
#          1.56890000e+01,   1.75840000e+01]), array([-40000.   , -44000.   , -36000.   , -21000.   , -42000.   ,
#        -36000.   , -42500.   , -44000.   , -48000.   , -45500.   ,
#        -43000.   , -45500.   , -43000.   , -28000.   , -43000.   ,
#        -28000.   , -25500.   , -38000.   , -38000.   , -28000.   ,
#        -33000.   , -35500.   , -35500.   , -30500.   , -35500.   ,
#        -33000.   , -35500.   , -35500.   , -40500.   , -35500.   ,
#        -38000.   , -33000.   , -35500.   , -30500.   , -25500.   ,
#        -28000.   , -30500.   , -33000.   , -32200.   , -37600.   ,
#        -30700.   , -33500.   , -32800.   , -23000.   , -32200.   ,
#        -29900.   , -25600.   , -27400.   , -34400.   , -32800.   ,
#        -32400.   , -26800.   , -21600.   , -42100.   , -24700.   ,
#        -31500.   , -44400.   , -27200.   , -35100.   , -40100.   ,
#        -39600.   , -37700.   , -41500.   , -26300.   , -21600.   ,
#        -41000.   , -37000.   , -38000.   , -37000.   , -38000.   ,
#        -37000.   , -42000.   , -37000.   , -39000.   , -36000.   ,
#        -37000.   , -36000.   , -37000.   , -37000.   , -37000.   ,
#        -44000.   , -42000.   , -42000.   , -36600.   , -39500.   ,
#        -35200.   , -36900.   , -36400.   , -41600.   , -32900.   ,
#        -38000.   , -37200.   , -31600.   , -40000.   , -41200.   ,
#        -43500.   , -34400.   , -39100.   , -44600.   , -43800.   ,
#        -39000.   , -47500.   , -40000.   , -46700.   , -49200.   ,
#        -40000.   , -40900.   , -40200.   , -39600.   , -36100.   ,
#        -37200.   , -38800.   , -39100.   , -39400.   , -38100.   ,
#        -37000.   , -32300.   , -39400.   , -44400.   , -39200.   ,
#        -42400.   , -39100.   , -37000.   , -36700.   , -35000.   ,
#        -36700.   , -37000.   , -38000.   , -34500.   , -44400.   ,
#        -37000.   , -36600.   , -40900.   , -37100.   , -38100.   ,
#        -36400.   , -34600.   , -35700.   , -38400.   , -42600.   ,
#        -26300.   , -34900.   , -38000.   , -41600.   , -36500.   ,
#        -37400.   , -26200.   , -45600.   , -34500.   , -40300.   ,
#        -37600.   , -33900.   , -37600.   , -37600.   , -33600.   ,
#        -38200.   , -36000.   , -41900.   , -32000.   , -32000.   ,
#        -40700.   , -42600.   , -38400.   , -31400.   , -40700.   ,
#        -39400.   , -43800.   , -45700.   , -33300.   , -37600.   ,
#        -35000.   , -35000.   , -32600.   , -41900.   , -35900.   ,
#        -36500.   , -35400.   , -35200.   , -35500.   , -38900.   ,
#        -34300.   , -35000.   , -35000.   , -36900.   , -38600.   ,
#        -38600.   , -38300.   , -37300.   , -33600.   , -37000.   ,
#        -35700.   , -33900.   , -38400.   , -40200.   , -39200.   ,
#        -48000.   , -38000.   , -37000.   , -40500.   , -36500.   ,
#        -35000.   , -35000.   , -38000.   , -40000.   , -38000.   ,
#        -37500.   , -37000.   , -37000.   , -44000.   , -41000.   ,
#        -36000.   , -34000.   , -41000.   , -42000.   , -41000.   ,
#        -42000.   , -41000.   , -36000.   , -34000.   , -30000.   ,
#        -38000.   , -37000.   , -37000.   , -27000.   , -30000.   ,
#        -25000.   , -37000.   , -44000.   , -27000.   , -33000.   ,
#        -35000.   , -39000.   , -42000.   , -37000.   , -40000.   ,
#        -38000.   , -38000.   , -40000.   , -36000.   , -43000.   ,
#        -38000.   , -33000.   , -38000.   , -33000.   , -45000.   ,
#        -42500.   , -45000.   , -42500.   , -45000.   , -42500.   ,
#        -40000.   , -42500.   , -43000.   , -37500.   , -43000.   ,
#        -43000.   , -40500.   , -40500.   , -42210.   , -43000.   ,
#        -40500.   , -40500.   , -43000.   , -35500.   , -40500.   ,
#        -38000.   , -36500.   , -38000.   , -38000.   , -40500.   ,
#        -35500.   , -38000.   , -35500.   , -35500.   , -38000.   ,
#        -37500.   , -35500.   , -37500.   , -38000.   , -35500.   ,
#        -33000.   , -35500.   , -38500.   , -46200.   , -34200.   ,
#        -36500.   , -38500.   , -49200.   , -37200.   , -39000.   ,
#        -36500.   , -42000.   , -38000.   , -34000.   , -30000.   ,
#        -32000.   , -30000.   , -24000.   , -30000.   , -30000.   ,
#        -29000.   , -28000.   , -34000.   , -32000.   , -32000.   ,
#        -28000.   , -21000.   , -22000.   , -24000.   , -21000.   ,
#        -21000.   , -24000.   , -27000.   , -25000.   , -31000.   ,
#        -27000.   , -30000.   , -39000.   , -33500.   , -48000.   ,
#        -34000.   , -42000.   , -41500.   , -46000.   , -44500.   ,
#        -43000.   , -45000.   , -48000.   , -38500.   , -48000.   ,
#        -41500.   , -43500.   , -41000.   , -38210.   , -39000.   ,
#        -41000.   , -36500.   , -36500.   , -38000.   , -37000.   ,
#        -40500.   , -46500.   , -39500.   , -42500.   , -41500.   ,
#        -46000.   , -34500.   , -43000.   , -44500.   , -54500.   ,
#        -43000.   , -41000.   , -39500.   , -41500.   , -41000.   ,
#        -38500.   , -39000.   , -38000.   , -43500.   , -41500.   ,
#        -41500.   , -44000.   , -48500.   , -39500.   , -37000.   ,
#        -38500.   , -39500.   , -36500.   , -39000.   , -43000.   ,
#        -37250.   , -37300.   , -37700.   , -34150.   , -44700.   ,
#        -42650.   , -28700.   , -32150.   , -32850.   , -31800.   ,
#        -33550.   , -27100.   , -31400.   , -39200.   , -34450.   ,
#        -30850.   , -24650.   , -28050.   , -35500.   , -41000.   ,
#        -40400.   , -44000.   , -42700.   , -26700.   , -24800.   ,
#        -32900.   , -32900.   , -25400.   , -31600.   , -32900.   ,
#        -35000.   , -42700.   , -41400.   , -33900.   , -24800.   ,
#        -37560.   , -34000.   , -32760.   , -32500.   , -33250.   ,
#        -28500.   , -32800.   , -41300.   , -41000.   , -35200.   ,
#        -33000.   , -44000.   , -23000.   , -39800.   , -38500.   ,
#        -33100.   , -35200.   , -36000.   , -39000.   , -30000.   ,
#        -30500.   , -38000.   , -34450.   , -20000.   , -28000.   ,
#        -29000.   , -31500.   , -34400.   , -20000.   , -22300.   ,
#        -32900.   , -43000.   , -43000.   , -43000.   , -43000.   ,
#        -39000.   , -39500.   , -40000.   , -40500.   , -40500.   ,
#        -39500.   , -36500.   , -31000.   , -45000.   , -44750.   ,
#        -43260.   , -42720.   , -42580.   , -41900.   , -44620.   ,
#        -45000.   , -44000.   , -45000.   , -30220.   , -35120.   ,
#        -34520.   , -38200.   , -35240.   , -25300.   , -25000.   ,
#        -21000.   , -21000.   , -20000.   , -20000.   , -29000.   ,
#        -34000.   , -36000.   , -34000.   , -37000.   , -38000.   ,
#        -37400.   , -30000.   , -35000.   , -34000.   , -36500.   ,
#        -38000.   , -42000.   , -41000.   , -41000.   , -40000.   ,
#        -40000.   , -32000.   , -30000.   , -29000.   , -30000.   ,
#        -28000.   , -27000.   , -34000.   , -30000.   , -35000.   ,
#        -34000.   , -34000.   , -40000.   , -39000.   , -38000.   ,
#        -27000.   , -28000.   , -29000.   , -28000.   , -27000.   ,
#        -35000.   , -35000.   , -34000.   , -38000.   , -33000.   ,
#        -30000.   , -40000.   , -37000.   , -35000.   , -29000.   ,
#        -35000.   , -38500.   , -38000.   , -37500.   , -37000.   ,
#        -36500.   , -36000.   , -35000.   , -34000.   , -35500.   ,
#        -37000.   , -39000.   , -41000.   , -33000.   , -34000.   ,
#        -36000.   , -37000.   , -41000.   , -42000.   , -40000.   ,
#        -34000.   , -35000.   , -40000.   , -42000.   , -42000.   ,
#        -45000.   , -45000.   , -34000.   , -38000.   , -41000.   ,
#        -29000.   , -30000.   , -36000.   , -48000.   , -42000.   ,
#        -35000.   , -33000.   , -40000.   , -23000.   , -22000.   ,
#        -26000.   , -26000.   , -28000.   , -28500.   , -27000.   ,
#        -31000.   , -35000.   , -35000.   , -31000.   , -35000.   ,
#        -33000.   , -37000.   , -36000.   , -38000.   , -38000.   ,
#        -39000.   , -38000.   , -36000.   , -37000.   , -40000.   ,
#        -39000.   , -40000.   , -38000.   , -40000.   , -39000.   ,
#        -35000.   , -24000.   , -29500.   , -31000.   , -33000.   ,
#        -29000.   , -28000.   , -38000.   , -38000.   , -36500.   ,
#        -33000.   , -35500.   , -35500.   , -30500.   , -35500.   ,
#        -33000.   , -35500.   , -35500.   , -40500.   , -35500.   ,
#        -38000.   , -33000.   , -35500.   , -30500.   , -25500.   ,
#        -28000.   , -30500.   , -33000.   , -11000.   , -13700.   ,
#        -34000.   , -32000.   , -31000.   , -31000.   , -31000.   ,
#        -33000.   , -31000.   , -32000.   , -32000.   , -32000.   ,
#        -33000.   , -32000.   , -33000.   , -31000.   , -33000.   ,
#        -34000.   , -33000.   , -33000.   , -33000.   , -30000.   ,
#        -31000.   , -35000.   , -32000.   , -38000.   , -38000.   ,
#        -38000.   , -35000.   , -36500.   , -38500.   , -39000.   ,
#        -33500.   , -38000.   , -39000.   , -34000.   , -39500.   ,
#        -41500.   , -43500.   , -36000.   , -46000.   , -41500.   ,
#        -49500.   , -45500.   , -39000.   , -45000.   , -39500.   ,
#        -33500.   , -44500.   , -42500.   , -41500.   , -41500.   ,
#        -43500.   , -40500.   , -43000.   , -41000.   , -43000.   ,
#        -46500.   , -39500.   , -41000.   , -46000.   , -50500.   ,
#        -40500.   , -38000.   , -37000.   , -41000.   , -44500.   ,
#        -43000.   , -41500.   , -46200.   , -46600.   , -45800.   ,
#        -43600.   , -37500.   , -40500.   , -37800.   , -41800.   ,
#        -39900.   , -39300.   , -44300.   , -34000.   , -38800.   ,
#        -40800.   , -42600.   , -40700.   , -43700.   , -42800.   ,
#        -42600.   , -41500.   , -42700.   , -44700.   , -36000.   ,
#        -38000.   , -43500.   , -37750.   , -36900.   , -40500.   ,
#        -36500.   , -46750.   , -40750.   , -39500.   , -38000.   ,
#        -44250.   , -37000.   , -39250.   , -48250.   , -42750.   ,
#        -39750.   , -39000.   , -40500.   , -42000.   , -25650.   ,
#        -25650.   , -25620.514, -25133.425, -24458.353, -24142.883,
#        -23998.738, -23545.543, -23143.239, -22749.693, -22199.757,
#        -22000.   , -21914.4  , -22027.287, -22276.215, -22659.811,
#        -23112.867, -23875.538, -24391.871, -24960.474, -25223.296,
#        -20900.   , -20997.601, -21046.346, -21187.697, -21439.557,
#        -21638.098, -21827.99 , -21944.981, -22066.692, -22187.249,
#        -22539.415, -23000.   , -23000.   , -23093.945, -23307.067,
#        -23376.733, -23720.1  , -24122.662, -26700.   , -26457.868,
#        -26165.935, -25758.98 , -25446.894, -25090.773, -24560.989,
#        -24001.356, -23478.759, -23247.525, -23102.721, -23048.27 ,
#        -23162.089, -23266.524, -23300.   , -23300.   , -23300.   ,
#        -23300.   , -23300.   , -23300.   , -23300.   , -23300.   ,
#        -23300.   , -23300.   , -23300.   , -23300.   , -23437.647,
#        -23665.384, -23854.146, -24076.779, -24581.316, -25099.447,
#        -25605.091, -25974.591, -26305.875, -26657.332, -26974.94 ,
#        -27418.472, -27886.363, -28407.495, -28909.729, -29361.209,
#        -29889.243, -30655.424, -31348.779, -31955.353, -32607.838,
#        -33271.121, -33677.359, -26400.   , -25691.988, -24548.985,
#        -23589.032, -22480.473, -21518.323, -21195.937, -21769.788,
#        -23337.652, -24000.   , -24000.   , -24000.   , -24000.   ,
#        -24382.455, -25814.393, -28629.445, -33734.297, -36636.15 ,
#        -37615.576, -38657.408, -39567.83 , -24000.   , -23400.021,
#        -22532.227, -22034.42 , -21533.14 , -21714.214, -22141.014,
#        -22300.   , -22343.058, -22682.987, -23000.   , -23000.   ,
#        -23000.   , -23000.   , -23000.   , -23000.   , -24056.554,
#        -26619.312, -30066.224, -31539.052, -32637.069, -34091.544,
#        -35613.841, -36597.643, -37557.097, -38216.061, -34000.   ,
#        -32000.   , -29000.   , -37000.   , -34500.   , -36000.   ,
#        -33500.   , -33500.   , -35500.   , -35000.   , -26000.   ,
#        -29000.   , -32500.   , -36500.   , -44000.   , -34000.   ,
#        -37000.   , -39000.   , -43000.   , -38000.   , -32500.   ,
#        -38000.   , -39000.   , -35500.   , -37000.   , -42500.   ,
#        -42000.   , -43500.   , -42000.   , -40000.   , -36000.   ,
#        -31000.   , -33000.   , -38000.   , -35000.   , -35000.   ])]

# %% [markdown]
# The longitude for the seismic points is in the range [-180, 180] but we need it in [0, 360] because the gravity data is  that way.

# %%
#test_points[1] += 360

# %% [markdown]
# Plot the seismic points.

# %%
x, y = bm(test_points[1], test_points[0])

plt.figure(figsize=(7, 6))
plt.title('Moho depth point constraints')
bm.scatter(x, y, c=-0.001*test_points[-1], s=20, cmap='Greens')
plt.colorbar(pad=0.01, aspect=50).set_label('km')
bm.drawmeridians(np.arange(20, 42+1, 2), labels=[0, 0, 0, 1], linewidth=0.2)
bm.drawparallels(np.arange(17, 37+1, 2), labels=[1, 0, 0, 0], linewidth=0.2)
bm.drawcoastlines(color="#666666")
plt.tight_layout()
plt.savefig('moho-depth-point-constrains.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# ## Inversion setup
#
# Create the objects and configuration that we'll need to run the inversions.

# %% [markdown]
# We need to generate a `TesseroidRelief` mesh for the inversion, give it a reference level and a density contrast.

# %%
area = (lat.min(), lat.max(), lon.min(), lon.max())
mesh = make_mesh(area, shape)

# %% [markdown]
# We'll also need an initial estimate, the solver and its configuration, and a regularization object.

# %%
misfit = MohoGravityInvSpherical(lat, lon, height, data, mesh)
regul = Smoothness2D(mesh.shape)
initial = -60e3*np.ones(mesh.size)
# The initial estimate doesn't really matter too much

# %% [markdown]
# ## Plotting functions
#
# We'll define some plotting functions here to avoid having all this code down with the results. You can safely skip (not read) this section because we only define the functions here. They are called after the inversion below.

# %%
def plot_fit(lat, lon, data, solution, bm):
    ranges = np.abs([data.max(), data.min()]).max()

    plt.figure(figsize=(7, 6))
    plt.title('Observed (color) and predicted (contour) data')
    levels = mpl.contourf(lon, lat, data, shape, 40, cmap='RdBu_r', basemap=bm,
                          vmin=-ranges, vmax=ranges)
    plt.colorbar(pad=0.01).set_label('mGal')
    mpl.contour(lon, lat, solution[0].predicted(), shape, levels,
                basemap=bm, color='#333333')
    bm.drawmeridians(np.arange(20, 42+1, 2), labels=[0, 0, 0, 1], linewidth=0.2)
    bm.drawparallels(np.arange(17, 37+1, 2), labels=[1, 0, 0, 0], linewidth=0.2)
    plt.tight_layout(pad=0)

def plot_residuals(solution):
    residuals = solution[0].residuals()

    plt.figure(figsize=(3, 2.5))
    plt.text(0.65, 0.8,
             "mean = {:.2f}\nstd = {:.2f}".format(residuals.mean(), residuals.std()),
             transform=plt.gca().transAxes)
    plt.hist(residuals, bins=20, normed=True, histtype='stepfilled')
    plt.xlabel('Residuals (mGal)')
    plt.ylabel('Normalized frequency')
    plt.tight_layout(pad=0)

def plot_estimate(solution, bm):
    moho = solution.estimate_
    x, y = bm(moho.lons, moho.lats)

    plt.figure(figsize=(7, 6))
    plt.title("Estimated Moho depth")
    bm.pcolormesh(x, y, -0.001*moho.relief.reshape(moho.shape), cmap='Greens')
    plt.colorbar(pad=0.01).set_label('km')
    bm.drawmeridians(np.arange(20, 42+1, 2), labels=[0, 0, 0, 1], linewidth=0.2)
    bm.drawparallels(np.arange(17, 37+1, 2), labels=[1, 0, 0, 0], linewidth=0.2)
    plt.tight_layout(pad=0)

def plot_diff_seismic(solution, test_points, bm):
    moho = solution.estimate_
    x, y = bm(moho.lons, moho.lats)
    diff = -0.001*(test_points[-1] - predict_seismic(moho, *test_points[:2]))
    ranges = np.abs([diff.max(), diff.min()]).max()
    lat, lon, depth = test_points
    xp, yp = bm(lon, lat)

    fig = plt.figure(figsize=(7, 6))
    bm.pcolormesh(x, y, -0.001*moho.relief.reshape(moho.shape), cmap='Greens')
    plt.colorbar(pad=0.01, aspect=50).set_label('Estimated Moho depth (km)')
    bm.scatter(xp, yp, c=diff, s=40, cmap='PuOr_r',
                     vmin=-ranges, vmax=ranges, linewidths=0.1)
    cb = plt.colorbar(pad=0.01, aspect=50)
    cb.set_label('Difference between seismic and estimated (km)')
    bm.drawmeridians(np.arange(20, 42+1, 2), labels=[0, 0, 1, 0], linewidth=0.2)
    bm.drawparallels(np.arange(17, 37+1, 2), labels=[1, 0, 0, 0], linewidth=0.2)
    plt.tight_layout(pad=0)

def plot_diff_seismic_hist(solution, test_points):
    moho = solution.estimate_
    diff = -0.001*(test_points[-1] - predict_seismic(moho, *test_points[:2]))

    plt.figure(figsize=(3, 2.5))
    plt.title('Difference (seismic points)')
    plt.text(0.65, 0.8,
             "mean = {:.2f}\nstd = {:.2f}".format(diff.mean(), diff.std()),
             transform=plt.gca().transAxes)
    # Use the line above so the text coordinates are in axes coordinates (0 to 1)
    # instead of data coordinates, which may vary between runs.
    plt.hist(diff, bins=20, normed=True, histtype='stepfilled')
    plt.xlabel('Differences (km)')
    plt.ylabel('Normalized frequency')
    plt.tight_layout(pad=0)

def plot_cv_regul(regul_params, scores, best, log=True):
    plt.figure(figsize=(5, 3))
    plt.title('Cross-validation (regularization parameter)')
    plt.plot(regul_params, scores, marker='o')
    plt.plot(regul_params[best], scores[best], 's', markersize=10,
             color=seaborn.color_palette()[2], label='Minimum')
    plt.legend(loc='upper left')
    plt.xscale('log')
    if log:
        plt.yscale('log')
    plt.xlabel('Regularization parameter')
    plt.ylabel(u'Mean Square Error')
    plt.tight_layout(pad=0)

def plot_cv_ref_dens(densities, reference_levels, scores, best_dens, best_ref):
    plt.figure(figsize=(5, 3))
    plt.title('Cross-validation (reference level and density)')
    plt.contourf(-0.001*reference_levels, densities, scores, 30, cmap='BuPu_r')
    plt.colorbar(pad=0.01).set_label('Mean Square Error')
    plt.plot(-0.001*reference_levels[best_ref], densities[best_dens], 's', markersize=10,
             color=seaborn.color_palette()[2], label='Minimum')
    l = plt.legend(loc='upper left')
    for txt in l.get_texts():
        txt.set_color('#ffffff')
    plt.xlabel('Reference level (km)')
    plt.ylabel(u'Density contrast (kg/m³)')
    plt.tight_layout(pad=0)

def plot_convergence(solution, log=True):
    plt.figure(figsize=(5, 3))
    plt.title('Convergence')
    plt.plot(range(solution.stats_['iterations'] + 1), solution.stats_['objective'])
    plt.xlabel('Iteration')
    plt.ylabel('Goal function')
    if log:
        plt.yscale('log')
    plt.tight_layout(pad=0)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Run the inversion and cross-validation

# %% [markdown]
# We'll keep the results in a Python dictionary (`dict`) along with all configuration and other metadata. We can then save this dict to a Pickle file and have inversion information saved with the results.

# %%
results = dict()

# %% [markdown]
# Save the configuration for the solver. We'll use the Gauss-Newton formulation of the inversion.

# %%
results['config'] = dict(method='newton', initial=initial, tol=0.2, maxit=6)

# %% [markdown]
# First, define the values of the regularization parameter, reference level, and density that we want to test during cross-validation.

# %%
results['regul_params'] = np.logspace(-10, -2, 16)
results['regul_params']
# Out:
# array([  1.00000000e-10,   3.41454887e-10,   1.16591440e-09,
#          3.98107171e-09,   1.35935639e-08,   4.64158883e-08,
#          1.58489319e-07,   5.41169527e-07,   1.84784980e-06,
#          6.30957344e-06,   2.15443469e-05,   7.35642254e-05,
#          2.51188643e-04,   8.57695899e-04,   2.92864456e-03,
#          1.00000000e-02])

# %%
results['reference_levels'] = np.arange(-50e3, -10e3 + 1, 2500)
results['reference_levels']
# Out:
# array([-50000., -47500., -45000., -42500., -40000., -37500., -35000.,
#        -32500., -30000., -27500., -25000., -22500., -20000., -17500.,
#        -15000., -12500., -10000.])

# %%
results['densities'] = np.arange(200, 600 + 1, 50)
results['densities']
# Out:
# array([200, 250, 300, 350, 400, 450, 500, 550, 600])

# %% [markdown]
# First, run the cross-validation to find the regularization parameter. We'll use one of the values for the reference and density contrast. The value of the regularization parameter that we estimate here will be used in the second cross-validation to find the density contrast and reference level.

# %%
misfit.set_density(results['densities'][-1]).set_reference(results['reference_levels'][-1])

# %% [markdown]
# Run the inversion for each value in `regul_params` (in parallel using all available cores).

# %%
solvers = [(misfit + mu*regul).config(**results['config'])
           for mu in results['regul_params']]

# %time solutions = fit_all(solvers, njobs=ncpu)
# Out:
# Wall time: 5min 1s

# %% [markdown]
# Keep only the estimated models in the results dict instead of the whole solvers to reduce the size of the pickle file. We can calculate the predicted data, etc, from the model only.

# %%
results['models_regul'] = [s.estimate_ for s in solutions]

# %% [markdown]
# Save these intermediate results in case something happens. This way we can resume computations from this point.

# %%
def pickle_results(results, intermediate=False):
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    results['metadata'] = "Generated by egy-moho.ipynb on {date}".format(
        date=now)
    if intermediate:
        fname = 'results/egy-moho.intermediate.pickle'
    else:
        fname = 'results/egy-america-moho.pickle'
    with open(fname, 'w') as f:
        pickle.dump(results, f)

# %%
pickle_results(results, intermediate=True)

# %% [markdown]
# Score the results against the test dataset.

# %%
# %%time
results['scores_regul'] = score_all(results['models_regul'], test_set, points=False,
                                    njobs=ncpu)
# Out:
# Wall time: 2min 10s

# %% [markdown]
# The best solution is the one with the smallest cross-validation score.

# %%
best_regul = np.argmin(results['scores_regul'])
results['best_regul'] = best_regul

# %% [markdown]
# We'll use this solution as the inversion solver for the next cross-validation (for the reference level and density).

# %%
results['solution_regul'] = solutions[best_regul]

# %% [markdown]
# Save the intermediate results again.

# %%
pickle_results(results, intermediate=True)

# %% [markdown]
# Take a look at the current solution. Plot the cross-validation scores, the inversion residuals, and the estimated solution.

# %%
plot_cv_regul(results['regul_params'], results['scores_regul'],
              best_regul, log=True)
plt.grid(True, which='both', axis='y')
plt.savefig('cross-validation scores1.png', dpi=500, bbox_inches='tight')

# %%
plot_residuals(results['solution_regul'])
plt.savefig('cross-validation-scores2.png', dpi=500, bbox_inches='tight')

# %%
plot_estimate(results['solution_regul'], bm)
plt.savefig('estimated-moho-depth1.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# Run the second cross-validation to estimate the density-contrast and the reference level.

# %%
def set_ref_dens(solver, ref, dens):
    """
    Configure the solver to use this reference level and density.
    """
    res = solver.copy(deep=True)
    # res is a multi-objective with the misfit function + regularization
    # res[0] is the misfit (our inversion class)
    # res[1] is the Smoothness2D instance
    res[0].set_density(dens).set_reference(ref)
    return res

# %%
solvers = [set_ref_dens(results['solution_regul'], ref, dens)
           for dens in results['densities']
           for ref in results['reference_levels']]

# %time solutions = fit_all(solvers, njobs=ncpu)
# Out:
# Wall time: 50min 54s

# %% [markdown]
# Keep the only the estimated models in the results dict.

# %%
type(solutions)
# Out:
# list

# %%
results['models_refdens'] = [s.estimate_ for s in solutions]
print(results)
# Out:
# {'models_regul': [<mohoinv.TesseroidRelief object at 0x000000001207D6D8>, <mohoinv.TesseroidRelief object at 0x000000001207D940>, <mohoinv.TesseroidRelief object at 0x000000001207D860>, <mohoinv.TesseroidRelief object at 0x000000001207DA20>, <mohoinv.TesseroidRelief object at 0x000000001207DC18>, <mohoinv.TesseroidRelief object at 0x0000000012093128>, <mohoinv.TesseroidRelief object at 0x0000000012093080>, <mohoinv.TesseroidRelief object at 0x0000000012093240>, <mohoinv.TesseroidRelief object at 0x0000000012093438>, <mohoinv.TesseroidRelief object at 0x0000000012093630>, <mohoinv.TesseroidRelief object at 0x0000000012093828>, <mohoinv.TesseroidRelief object at 0x0000000012093A20>, <mohoinv.TesseroidRelief object at 0x0000000012093E48>, <mohoinv.TesseroidRelief object at 0x0000000012075048>, <mohoinv.TesseroidRelief object at 0x00000000120751D0>, <mohoinv.TesseroidRelief object at 0x0000000012075390>], 'densities': array([200, 250, 300, 350, 400, 450, 500, 550, 600]), 'reference_levels': array([-50000., -47500., -45000., -42500., -40000., -37500., -35000.,
#        -32500., -30000., -27500., -25000., -22500., -20000., -17500.,
#        -15000., -12500., -10000.]), 'scores_regul': array([  29.10700713,   29.10701171,   29.10702738,   29.10708086,
#          29.10726354,   29.1078878 ,   29.11002532,   29.1173938 ,
#          29.14332186,   29.22598029,   29.50665968,   30.40472666,
#          33.04050554,   40.42459625,   63.41006298,  135.94144682]), 'models_refdens': [<mohoinv.TesseroidRelief object at 0x000000000FD20E48>, <mohoinv.TesseroidRelief object at 0x000000000FD29128>, <mohoinv.TesseroidRelief object at 0x000000000FD292E8>, <mohoinv.TesseroidRelief object at 0x000000000FD29588>, <mohoinv.TesseroidRelief object at 0x000000000FD29748>, <mohoinv.TesseroidRelief object at 0x000000000FD29908>, <mohoinv.TesseroidRelief object at 0x000000000FD29AC8>, <mohoinv.TesseroidRelief object at 0x000000000FD29C88>, <mohoinv.TesseroidRelief object at 0x000000000FD29E48>, <mohoinv.TesseroidRelief object at 0x000000000FD10048>, <mohoinv.TesseroidRelief object at 0x000000000FD20F28>, <mohoinv.TesseroidRelief object at 0x000000000FD103C8>, <mohoinv.TesseroidRelief object at 0x000000000FD10588>, <mohoinv.TesseroidRelief object at 0x000000000FD10748>, <mohoinv.TesseroidRelief object at 0x000000000FD10908>, <mohoinv.TesseroidRelief object at 0x000000000FD10AC8>, <mohoinv.TesseroidRelief object at 0x000000000FD10C88>, <mohoinv.TesseroidRelief object at 0x000000000FD10E48>, <mohoinv.TesseroidRelief object at 0x00000000111FE048>, <mohoinv.TesseroidRelief object at 0x00000000111FE208>, <mohoinv.TesseroidRelief object at 0x000000000FD10208>, <mohoinv.TesseroidRelief object at 0x00000000111FE588>, <mohoinv.TesseroidRelief object at 0x00000000111FE748>, <mohoinv.TesseroidRelief object at 0x00000000111FE908>, <mohoinv.TesseroidRelief object at 0x00000000111FEAC8>, <mohoinv.TesseroidRelief object at 0x00000000111FEC88>, <mohoinv.TesseroidRelief object at 0x00000000111FEE48>, <mohoinv.TesseroidRelief object at 0x00000000111E3048>, <mohoinv.TesseroidRelief object at 0x00000000111E3208>, <mohoinv.TesseroidRelief object at 0x00000000111E33C8>, <mohoinv.TesseroidRelief object at 0x00000000111FE4A8>, <mohoinv.TesseroidRelief object at 0x00000000111E3748>, <mohoinv.TesseroidRelief object at 0x00000000111E3908>, <mohoinv.TesseroidRelief object at 0x00000000111E3AC8>, <mohoinv.TesseroidRelief object at 0x00000000111E3C88>, <mohoinv.TesseroidRelief object at 0x00000000111E3E48>, <mohoinv.TesseroidRelief object at 0x00000000111DB048>, <mohoinv.TesseroidRelief object at 0x00000000111DB208>, <mohoinv.TesseroidRelief object at 0x00000000111DB3C8>, <mohoinv.TesseroidRelief object at 0x00000000111DB588>, <mohoinv.TesseroidRelief object at 0x00000000111E35F8>, <mohoinv.TesseroidRelief object at 0x00000000111DB908>, <mohoinv.TesseroidRelief object at 0x00000000111DBAC8>, <mohoinv.TesseroidRelief object at 0x00000000111DBC88>, <mohoinv.TesseroidRelief object at 0x00000000111DBE48>, <mohoinv.TesseroidRelief object at 0x000000000E666F60>, <mohoinv.TesseroidRelief object at 0x000000000E666E10>, <mohoinv.TesseroidRelief object at 0x000000000E666C50>, <mohoinv.TesseroidRelief object at 0x000000000E666A90>, <mohoinv.TesseroidRelief object at 0x000000000E666908>, <mohoinv.TesseroidRelief object at 0x00000000111DB828>, <mohoinv.TesseroidRelief object at 0x000000000E666748>, <mohoinv.TesseroidRelief object at 0x000000000E666668>, <mohoinv.TesseroidRelief object at 0x000000000E666518>, <mohoinv.TesseroidRelief object at 0x000000000E63C048>, <mohoinv.TesseroidRelief object at 0x000000000E63C208>, <mohoinv.TesseroidRelief object at 0x000000000E63C3C8>, <mohoinv.TesseroidRelief object at 0x000000000E63C588>, <mohoinv.TesseroidRelief object at 0x000000000E63C748>, <mohoinv.TesseroidRelief object at 0x000000000E63C908>, <mohoinv.TesseroidRelief object at 0x000000000E6667F0>, <mohoinv.TesseroidRelief object at 0x000000000E63CC88>, <mohoinv.TesseroidRelief object at 0x000000000E63CE48>, <mohoinv.TesseroidRelief object at 0x000000000E655048>, <mohoinv.TesseroidRelief object at 0x000000000E655208>, <mohoinv.TesseroidRelief object at 0x000000000E6553C8>, <mohoinv.TesseroidRelief object at 0x000000000E655588>, <mohoinv.TesseroidRelief object at 0x000000000E655748>, <mohoinv.TesseroidRelief object at 0x000000000E655908>, <mohoinv.TesseroidRelief object at 0x000000000E6 ...
#          3.98107171e-09,   1.35935639e-08,   4.64158883e-08,
#          1.58489319e-07,   5.41169527e-07,   1.84784980e-06,
#          6.30957344e-06,   2.15443469e-05,   7.35642254e-05,
#          2.51188643e-04,   8.57695899e-04,   2.92864456e-03,
#          1.00000000e-02]), 'solution_regul': <fatiando.inversion.base.MultiObjective object at 0x000000000DCC8E10>, 'config': {'initial': array([-60000., -60000., -60000., ..., -60000., -60000., -60000.]), 'maxit': 6, 'method': 'newton', 'tol': 0.2}, 'metadata': 'Generated by south-america-moho.ipynb on 07 December 2022 08:04:35 UTC'}

# %% [markdown]
# Now lets save ALL moho models

# %%
lat = results['models_refdens'][0].clat.ravel()
lon = results['models_refdens'][0].clon.ravel()
nrows = lat.shape[0]
ncols = results['densities'].shape[0]*results['reference_levels'].shape[0]+2
model_data = np.zeros((nrows, ncols))
model_header = 'lat;lon;'

model_data[:,0] = lat
model_data[:,1] = lon
i=0
for dens in results['densities']:
    for ref in results['reference_levels']:
        model_header = model_header + str(dens) + '<>' + str(ref) + ';'
        #print(str(i)+': '+str(dens) + '<>' + str(ref))
        model_data[:,i+2] = results['models_refdens'][i].relief
        #print(results['models_refdens'][i])
        i = i+1

#print(model_header)
#print(model_data)

with open('../code/results/Egypt_Moho_Models.txt', 'w') as f:
    f.write(model_header)
    np.savetxt(f, model_data,fmt='%.5f')

# %%
now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
moho = results ['solution'].estimate_
header = """# Moho of egypt estimated by gravity data inversion
# See the source code for the inversion at:
#   https://github.com/pinga-lab/paper-moho-inversion-tesseroids
# Model grid shape (nlat, nlon):
#   {nlat} {nlon}
# Latitude and longitude values correspond to the center of each
# model cell.
# Moho depth is provided in meters.
# Columns:
# lat lon Moho_depth
""".format(date=now, nlat=moho.shape[0], nlon=moho.shape[1])
with open('../model/Egypt-moho_Models2.txt', 'w') as f:
    f.write(header)
    np.savetxt(f, np.c_[moho.clat.ravel(), moho.clon.ravel(), -moho.relief],
               fmt='%.5f')

# %% [markdown]
# Score the estimates against the seismic constraints.

# %%
# Reshape the scores array because it should be a matrix
# with density as the rows and reference level as the columns.
# This will make it easier for us to find the best density and reference level below.
cv_shape = (len(results['densities']), len(results['reference_levels']))
results['scores_refdens'] = score_all(results['models_refdens'],
                                      test_points, points=True).reshape(cv_shape)

# %%
best = np.nanargmin(results['scores_refdens'])
# Find the index in reference_levels and densities corresponding to best
results['best_dens'], results['best_ref'] = np.unravel_index(best, cv_shape)
results['solution'] = solutions[best]

# %% [markdown]
# Print the estimated parameters:

# %%
estimated_ref = results['reference_levels'][results['best_ref']]
estimated_dens = results['densities'][results['best_dens']]
estimated_regul = results['regul_params'][results['best_regul']]
print('Cross-validation results:')
print(u'  reference level: {} km'.format(-0.001*estimated_ref))
print(u'  density contrast: {} kg/m³'.format(estimated_dens))
print(u'  regularization parameter: {}'.format(estimated_regul))
# Out:
# Cross-validation results:
#   reference level: 35.0 km
#   density contrast: 600 kg/m³
#   regularization parameter: 1e-10

# %% [markdown]
# ## Save the results

# %% [markdown]
# Save the final results into a pickle file.

# %%
pickle_results(results, intermediate=False)

# %% [markdown]
# Since the resulting pickle file will be large, we'll store it in a `zip` archive.

# %%
fname = 'south-america-moho'
pickle_file = '{}.pickle'.format(fname)
# Zip the pickle file
zipargs = dict(mode='w', compression=zipfile.ZIP_DEFLATED)
with zipfile.ZipFile('results/{}.zip'.format(fname), **zipargs) as f:
    f.write('results/{}'.format(pickle_file), arcname=pickle_file)

# %% [markdown]
# The zip file is still too large for [Github](https://github.com/) (maximum allowed is 50 Mb). The way to store and commit the file is to split it into two with the `split` command-line program. We can assemble the two parts again using the `cat` program (see [paper-figures.ipynb](paper-figures.ipynb) for an example).

# %%
#%%bash
#cd results/
#split -b 30M --numeric-suffixes=1 south-america-moho.zip south-america-moho.zip.part
#cd ..

# %% [markdown]
# Also save the estimated Moho to a text file in xyz format for portability.

# %%
now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
moho = results['solution'].estimate_
header = """# Moho of Egypt estimated by gravity data inversion
# See the source code for the inversion at:
#   https://github.com/pinga-lab/paper-moho-inversion-tesseroids
# Model grid shape (nlat, nlon):
#   {nlat} {nlon}
# Latitude and longitude values correspond to the center of each
# model cell.
# Moho depth is provided in meters.
# Columns:
# lat lon Moho_depth
""".format(date=now, nlat=moho.shape[0], nlon=moho.shape[1])
with open('../model/Egypt_moho_model3.txt', 'w') as f:
    f.write(header)
    np.savetxt(f, np.c_[moho.clat.ravel(), moho.clon.ravel(), -moho.relief],
               fmt='%.5f')

# %% [markdown]
# ## Make quick plots of the results

# %%
plot_cv_ref_dens(results['densities'], results['reference_levels'],
                 results['scores_refdens'], results['best_dens'],
                 results['best_ref'])
plt.savefig('cross2.png', dpi=500, bbox_inches='tight')

# %%
plot_fit(lat, lon, data, results['solution'], bm)
plt.savefig('obs-vs-pred.png', dpi=500, bbox_inches='tight')

# %%
plot_residuals(results['solution'])
plt.savefig('resd.png', dpi=500, bbox_inches='tight')

# %%
plot_estimate(results['solution'], bm)
plt.savefig('estimated-moho-depthh2.png', dpi=500, bbox_inches='tight')

# %%
plot_diff_seismic(results['solution'], test_points, bm)
plt.savefig('siesmic-estimated.png', dpi=500, bbox_inches='tight')

# %%
plot_diff_seismic_hist(results['solution'], test_points)
plt.savefig('diff.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# []()
